# %%
import numpy as np
from scipy.ndimage import convolve
from matplotlib import pyplot as plt
# %matplotlib inline
channels = 5 # number of channels to simulate
hw = 256 # height and width dimensions

# Create some Activation tensors
A1 = np.random.randn(channels,hw,hw)
A2 = np.random.rand(channels,hw,hw)

# make A1 low frequency  
filt = np.ones((3,6,6))
filt = filt / np.sum(filt)
A1 = convolve(A1,filt)
A1 = A1 - np.mean(A1)

# make A2 high frequency
filt = np.ones((2,3,3))
filt = filt / np.sum(filt)
filt[:,:,0] = filt[:,:,0]*(-1)
filt[:,:,1] = 0
A2 = convolve(A2,filt)
A2 = A2 - np.mean(A2)

# plot each tensor, average along channel
def show_active(A,title=''):
    plt.imshow(np.mean(A,0))
    plt.title(title)

n_plots = min(channels,10)
plt.figure(figsize=(15,5))   
for i in range(n_plots):
    plt.subplot(1,n_plots,i+1)
    plt.imshow(A1[i,:,:])
    plt.title(f'A1 at {i}')
    
n_plots = min(channels,10)
plt.figure(figsize=(15,5))   
for i in range(n_plots):
    plt.subplot(1,n_plots,i+1)
    plt.imshow(A2[i,:,:])
    plt.title(f'A2 at {i}')
    
plt.figure()
plt.subplot(1,2,1)
show_active(A1,'A1 Mean over channels')
plt.subplot(1,2,2)
show_active(A2,'A2 Mean over channels')

# %%
# calculate gram matrix (vectorized spatially) and show it
# for each activations
def gram(x):
    tmp = x.reshape((channels,hw*hw))
    return tmp @ tmp.T / (channels*hw*hw)

def show_gram(A,title=''):
    plt.figure()
    G = gram(A)
    plt.subplot(1,2,2)
    plt.imshow(G)
    plt.title('Gram of '+title)
    plt.subplot(1,2,1)
    show_active(A,title)
    return G
    

G_A1 = show_gram(A1,'A1')
G_A2 = show_gram(A2,'A2')

# %% [markdown]
# In order to whiten an output convolution (activation), we can use its SVD decomposition as follows:
#
# $$
# \begin{align}
# A_f =& flatten(A) \\
# A_f =& U\cdot\Sigma\cdot V^T \\
# A_{wf} =& U\cdot V^T \\
# A_{white} =& reshape(A_{wf}) \\
# \end{align}
# $$

# %%
# apply whitening (get relevant SVD vectors)
def whiten(A):
    Avec = A.reshape((channels,hw*hw))
    u,s,vt = np.linalg.svd(Avec,full_matrices=False)
    A_white = (u @ vt).reshape((channels,hw,hw)) # no usage of the singular values here
    return A_white, (u, s, vt), Avec
    
A1_white, A1SVD, A1vec = whiten(A1)
A2_white, A2SVD, A2vec = whiten(A2)

G_A1_white = show_gram(A1_white,'A1_white')
G_A2_white = show_gram(A2_white,'A2_white')

# %% [markdown]
# Now we can transfer the covariances of the activations (i.e., the Grammian) from one matrix to another. This can be achieved in a few ways. The first is given by:
#
# $$
# \begin{align}
# \widehat{A}_{c} =& flatten(A_c) &\widehat{A}_{s} =& flatten(A_s) \\
# \widehat{A}_{c} =& U_c\cdot\Sigma_c\cdot V_c^T & \widehat{A}_{s} =& U_s\cdot\Sigma_s\cdot V_s^T \\
# \widehat{A}_{s\leftarrow c} =& \underbrace{U_s\cdot\Sigma_s}_{\text{from s}}\underbrace{\cdot V_c^T}_{\text{from c}} &\widehat{A}_{c\leftarrow s} =& \underbrace{U_c\cdot\Sigma_c}_{\text{from c}}\underbrace{\cdot V_s^T}_{\text{from s}} \\
# A_{s\leftarrow c} =& reshape(\widehat{A}_{s\leftarrow c}) & A_{c\leftarrow s} =& reshape(\widehat{A}_{c\leftarrow sf}) \\
# \end{align}
# $$

# %%
u1, s1, v1 = A1SVD
u2, s2, v2 = A2SVD

# Apply coloring 
A1_color_as_A2 = (u2 @ np.diag(s2) @ v1).reshape((channels,hw,hw))
A2_color_as_A1 = (u1 @ np.diag(s1) @ v2).reshape((channels,hw,hw))

# show originals
# and colored versions
diffA1 = np.mean((A1_color_as_A2-A1)**2)
diffA2 = np.mean((A2_color_as_A1-A2)**2)

G_A1 = show_gram(A1,'A1')
G_A1asA2 = show_gram(A1_color_as_A2,'A1_color_as_A2')

G_A2 = show_gram(A2,'A2')
G_A2asA1 = show_gram(A2_color_as_A1,'A2_color_as_A1')

print('A1 average content difference:', diffA1)
print('A2 average content difference:', diffA2)

print('A1 colored average Grammian difference:', np.mean((G_A2-G_A1asA2)**2))
print('A2 colored average Grammian difference:', np.mean((G_A1-G_A2asA1)**2))
# Out:
# A1 average content difference: 0.010165247672381432
# A2 average content difference: 0.01016524767238143
# A1 colored average Grammian difference: 3.223107504261156e-37
# A2 colored average Grammian difference: 2.2141170781707048e-36

# %% [markdown]
# ____
# ## But that will not work for large images or a large number of channels
# Now, there is a (potentially) slight problem with the matrices above. Notice that the SVD above requires that we decompose the entire matrix A, which might be very large an have numerous channels. What if we could use the SVD of only the covariance matrix?
#
# The preivous SVD transformations required VERY precise computation for the SVD. And, they require that the A1 and A2 activations are the exact same size. That is really limiting. We can get the same results by first calcualting the SVD of the covariance matrix and applying these to the activations? Yes! We can perform a much simpler SVD in this way. Since we are taking the SVD of a square matrix, $U = V^T$. That is, the left and right eigenvectors are just the transpose of one another. So we do not need to calculate both.
#
# $$
# \begin{align}
# Af_{c} =& flatten(A_c) & Af_{s} =& flatten(A_s) \\
# U_c,\Sigma_c,U_c^T =& \text{SVD}(Af_{c}\cdot Af_{c}^T) &
# U_s,\Sigma_s,U_s^T =& \text{SVD}(Af_{s}\cdot Af_{s}^T) \\
# \widehat{Af}_{c} =& U_c\cdot\frac{1}{\sqrt{\Sigma_c}}\cdot U_c^T \cdot Af_{c} &
# \widehat{Af}_{s} =& U_s\cdot\frac{1}{\sqrt{\Sigma_s}}\cdot U_s^T \cdot Af_{s} \\
# \widehat{A}_{s\leftarrow\approx c} =& \underbrace{U_s\cdot\sqrt{\Sigma_s}\cdot U_s^T}_{\text{Desired Cov.}} \cdot \underbrace{\widehat{Af}_{c}}_{\text{Whitened}}   &
# \widehat{A}_{c\leftarrow\approx s} =& U_c\cdot\sqrt{\Sigma_c}\cdot U_c^T \cdot \widehat{Af}_{s}  \\
# A_{s\leftarrow\approx c} =& reshape(\widehat{A}_{s\leftarrow\approx c}) & A_{c\leftarrow\approx s} =& reshape(\widehat{A}_{c\leftarrow\approx sf}) \\
# \end{align}
# $$

# %%
# apply whitening (get relevant SVD vectors)
def whiten_cov(A):
    Avec = A.reshape((channels,hw*hw))
    AA = Avec @ Avec.T
    # notice that the SVD is of the covariance matrix
    u,s,vt = np.linalg.svd(AA,full_matrices=False)
    
    A_white = ((u @ np.diag(s**(-0.5)) @ vt) @ Avec) # no usage of the singular values here
    return A_white, (u, s, vt), Avec
    

A1_white, A1SVDcov, A1vec = whiten_cov(A1)
A2_white, A2SVDcov, A2vec = whiten_cov(A2)
    
u1, s1, _ = A1SVDcov
u2, s2, _ = A2SVDcov

# -------A1-------
# Apply inverse reconstruction to get colored version
A1_mixed_color = u2 @ np.diag(s2**(0.5)) @ u2.T @ A1_white
A1_mixed_color = A1_mixed_color.reshape((channels,hw,hw))

# -------A2-------
# Apply inverse reconstruction to get colored version
A2_mixed_color = u1 @ np.diag(s1**(0.5)) @ u1.T @ A2_white
A2_mixed_color = A2_mixed_color.reshape((channels,hw,hw))

diffA1 = np.mean((A1_mixed_color-A1)**2)
diffA2 = np.mean((A2_mixed_color-A2)**2)

# show originals
# and colored versions
G_A1 = show_gram(A1,'A1')
_ = show_gram(A1_white.reshape((channels,hw,hw)),'A1_white')
G_A1asA2 = show_gram(A1_mixed_color,'A1_mixed_color')

# show originals
# and colored versions
G_A1 = show_gram(A2,'A2')
_ = show_gram(A2_white.reshape((channels,hw,hw)),'A2_white')
G_A2asA1 = show_gram(A2_mixed_color,'A2_mixed_color')

print('A1 average content difference:', diffA1)
print('A2 average content difference:', diffA2)

print('A1 colored average Grammian difference:', np.mean((G_A2-G_A1asA2)**2))
print('A2 colored average Grammian difference:', np.mean((G_A1-G_A2asA1)**2))
# Out:
# A1 average content difference: 0.002921664968702935
# A2 average content difference: 0.0029216649687029235
# A1 colored average Grammian difference: 6.774779311408603e-37
# A2 colored average Grammian difference: 1.208307471071041e-06

# %% [markdown]
# Notice also that the activations are much closer in content to one another, but the values from the Grammian are also transferred exactly. See the differences compared to using the left and right eigenvectors from SVD of the activations.
# Moreover, if you run these code with in increased number of channels, you get an even more stark advantage.
#
# For example, we have:
#  - Using SVD of $A$, mean squared error difference:
#    - 5 Channels:  0.01059
#    - 512 Channels: 0.012620
#  - Using SVD of $\text{Cov}(A\cdot A^T)$, mean squared error difference:
#    - 5 Channels: 0.002936
#    - 512 Channels: 0.002577
#
# That extra accumulated error can be disatrous when we place it through a neural network. For the SVD of the covariance, we are a full order of magnitude better...
#
# ___
# ## Mixing the activations
# The colored matrices have the exact Grammian that we want, but do we want the Grammian matrices to be identical? What if that causes some image artifacts from transfering too much style into the activations? Would it be better if we only partially colored the matrices such that the Grammian were more mixed? The answer is not immediately clear, but we have the math to test it out. This partial coloring can be achieved using a weighted sum of the original activations and the transferred activations, as follows:.

# %%
# Another trick we can use to insert more content
# back into the matrix is to take a weighted sum
# of the colored contetn and original content 
for alpha in [0.1, 0.25, 0.5, 0.75, 0.9]:
    show_gram(alpha*A1_mixed_color+(1-alpha)*A1,f'A1+A1_mixed,a={alpha}')
